# %% [markdown]
# # Data exploration

# %% [markdown]
# ### Explore bronze database and show what tables are present

# %%
import sqlite3
import pandas as pd
from collections import defaultdict

# Connect to the bronze database
conn = sqlite3.connect('../data/1_bronze/bronze_data.db')
cursor = conn.cursor()

# Get list of all tables in bronze database
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

# Group tables by prefix
table_groups = defaultdict(list)
for table in tables:
    table_name = table[0]
    prefix = table_name.split('_', 1)[0]  # Extract prefix before first underscore
    table_groups[prefix].append(table_name)

# Display grouped tables
print("Tables grouped by prefix:")
for prefix, table_list in sorted(table_groups.items()):
    print(f"\n{prefix}:")
    for t in table_list:
        print(f"  - {t}")
# Out:
# Tables grouped by prefix:
#
# 80072ned:
#   - 80072ned_dim_BedrijfskenmerkenSBI2008
#   - 80072ned_dim_CategoryGroups
#   - 80072ned_dim_DataProperties
#   - 80072ned_dim_Perioden
#   - 80072ned_dim_TableInfos
#   - 80072ned_fact
#
# 83157NED:
#   - 83157NED_dim_BedrijfstakkenBranchesSBI2008
#   - 83157NED_dim_CategoryGroups
#   - 83157NED_dim_DataProperties
#   - 83157NED_dim_Marges
#   - 83157NED_dim_Perioden
#   - 83157NED_dim_TableInfos
#   - 83157NED_fact
#
# 83415NED:
#   - 83415NED_dim_DataProperties
#   - 83415NED_dim_Marges
#   - 83415NED_dim_Perioden
#   - 83415NED_dim_TableInfos
#   - 83415NED_fact
#
# sample:
#   - sample_org

# %%
# Get all table names starting with '80072ned'
tables_80072ned = table_groups['80072ned']

# Load each table into a DataFrame and store in a dictionary
dfs_80072ned = {table: pd.read_sql_query(f"SELECT * FROM [{table}]", conn) for table in tables_80072ned}

# Show the keys (table names) and preview the first table
print("Loaded tables:", list(dfs_80072ned.keys()))
dfs_80072ned[tables_80072ned[0]].head()
# Out:
# Loaded tables: ['80072ned_dim_BedrijfskenmerkenSBI2008', '80072ned_dim_CategoryGroups', '80072ned_dim_DataProperties', '80072ned_dim_Perioden', '80072ned_dim_TableInfos', '80072ned_fact']
#                                bronze_pk      Key  \
# 0  BedrijfskenmerkenSBI2008.json_T001081  T001081
# 1   BedrijfskenmerkenSBI2008.json_301000   301000
# 2   BedrijfskenmerkenSBI2008.json_305700   305700
# 3   BedrijfskenmerkenSBI2008.json_300003   300003
# 4   BedrijfskenmerkenSBI2008.json_307500   307500
#
#                                Title  \
# 0  A-U Alle economische activiteiten
# 1    A Landbouw, bosbouw en visserij
# 2               B Delfstoffenwinning
# 3          B-F Nijverheid en energie
# 4                        C Industrie
#
#                                          Description  CategoryGroupID  \
# 0  Alle economische activiteiten \r\nDeze categor...                1
# 1  Landbouw, bosbouw en visserij \r\nDeze sectie ...                2
# 2  Winning van delfstoffen \r\nDeze sectie omvat:...                3
# 3  Nijverheid en energie \r\nDeze categorie is ee...                2
# 4  Industrie \r\nDeze sectie omvat: \r\n- de mech...                3
#
#                     _source_file
# 0  BedrijfskenmerkenSBI2008.json
# 1  BedrijfskenmerkenSBI2008.json
# 2  BedrijfskenmerkenSBI2008.json
# 3  BedrijfskenmerkenSBI2008.json
# 4  BedrijfskenmerkenSBI2008.json

# %% [markdown]
# ### Read all content from the 80072ned tables in database bronze_data and merge the tables on keys.

# %%
# Get fact table from the loaded dataframes
fact_df = dfs_80072ned['80072ned_fact']

# Get the dimension tables
periode_df = dfs_80072ned['80072ned_dim_Perioden']
bedrijfs_df = dfs_80072ned['80072ned_dim_BedrijfskenmerkenSBI2008']
category_df = dfs_80072ned['80072ned_dim_CategoryGroups']

# Perform the joins
enriched_fact = fact_df.merge(periode_df, left_on='Perioden', right_on='Key', how='left', suffixes=('', '_periode'))
enriched_fact = enriched_fact.merge(bedrijfs_df, left_on='BedrijfskenmerkenSBI2008', right_on='Key', how='left', suffixes=('', '_bedrijfs'))
enriched_fact = enriched_fact.merge(category_df, left_on='CategoryGroupID', right_on='ID', how='left', suffixes=('', '_category'))

# # Select and rename columns
enriched_fact = enriched_fact[['ID', 'BedrijfskenmerkenSBI2008', 'Perioden', 'Ziekteverzuimpercentage_1' ,'Title', 'Description', 'Status', 'Key_bedrijfs', 'Title_bedrijfs', 'Description_bedrijfs', 'CategoryGroupID', 'ID_category', 'DimensionKey', 'Title_category', 'Description_category', 'ParentID']]
# enriched_fact.columns = ['fact_ID', 'Ziekteverzuimpercentage_1', 'periode_key', 'periode_title', 'periode_description', 'periode_status', 'bedrijfs_key', 'bedrijfs_title', 'bedrijfs_description', 'CategoryGroupID', 'category_id', 'category_dimension_key', 'category_title', 'category_description', 'category_parent_id']

print(enriched_fact.columns)
print(enriched_fact.head())

# # Close the database connection
conn.close()
# Out:
# Index(['ID', 'BedrijfskenmerkenSBI2008', 'Perioden',
#        'Ziekteverzuimpercentage_1', 'Title', 'Description', 'Status',
#        'Key_bedrijfs', 'Title_bedrijfs', 'Description_bedrijfs',
#        'CategoryGroupID', 'ID_category', 'DimensionKey', 'Title_category',
#        'Description_category', 'ParentID'],
#       dtype='object')
#    ID BedrijfskenmerkenSBI2008  Perioden  Ziekteverzuimpercentage_1  \
# 0   0                  T001081  1996KW01                        5.5
# 1   1                  T001081  1996KW02                        4.6
# 2   2                  T001081  1996KW03                        4.0
# 3   3                  T001081  1996KW04                        4.7
# 4   4                  T001081  1996JJ00                        4.7
#
#               Title Description      Status Key_bedrijfs  \
# 0  1996 1e kwartaal              Definitief      T001081
# 1  1996 2e kwartaal              Definitief      T001081
# 2  1996 3e kwartaal              Definitief      T001081
# 3  1996 4e kwartaal              Definitief      T001081
# 4              1996              Definitief      T001081
#
#                       Title_bedrijfs  \
# 0  A-U Alle economische activiteiten
# 1  A-U Alle economische activiteiten
# 2  A-U Alle economische activiteiten
# 3  A-U Alle economische activiteiten
# 4  A-U Alle economische activiteiten
#
#                                 Description_bedrijfs  CategoryGroupID  \
# 0  Alle economische activiteiten \r\nDeze categor...                1
# 1  Alle economische activiteiten \r\nDeze categor...                1
# 2  Alle economische activiteiten \r\nDeze categor...                1
# 3  Alle economische activiteiten \r\nDeze categor...                1
# 4  Alle economische activiteiten \r\nDeze categor...                1
#
#    ID_category              DimensionKey Title_category Description_category  \
# 0            1  BedrijfskenmerkenSBI2008         Totaal
# 1            1  BedrijfskenmerkenSBI2008         Totaal
# 2            1  BedrijfskenmerkenSBI2008         Totaal
# 3            1  BedrijfskenmerkenSBI2008         Totaal
# 4            1  BedrijfskenmerkenSBI2008         Totaal
#
#   ParentID
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %% [markdown]
# ### Which variables are numerical? And which are strings? How many variables do we have of both types? How many observations do we have? Suggestion: Split the original data in a data frame containing the numerical data and a data frame containing the string data.

# %% [markdown]
# **numerical data:**
#
# The numerical type allows mathematical operations.

# %%
# Using Pandas.
df_pd_enriched_num    = enriched_fact.select_dtypes(include='number')

# Column names (Pandas: df_pd_orig_num.columns.tolist()).
l_df_num_names = df_pd_enriched_num.columns

print(f"We have {len(l_df_num_names)} numerical variables:\n{l_df_num_names}")
# Out:
# We have 4 numerical variables:
# Index(['ID', 'Ziekteverzuimpercentage_1', 'CategoryGroupID', 'ID_category'], dtype='object')

# %%
# In Pandas.
df_pd_enriched_str    = enriched_fact.select_dtypes(include='object')

# Column names (Pandas: df_pd_orig_str.columns.tolist()).
l_df_str_names = df_pd_enriched_str.columns

print(f"We have {len(l_df_str_names)} string variables:\n{l_df_str_names}")
# Out:
# We have 12 string variables:
# Index(['BedrijfskenmerkenSBI2008', 'Perioden', 'Title', 'Description',
#        'Status', 'Key_bedrijfs', 'Title_bedrijfs', 'Description_bedrijfs',
#        'DimensionKey', 'Title_category', 'Description_category', 'ParentID'],
#       dtype='object')

# %% [markdown]
# Do we have all columns in both data frames? Yes, we do!

# %%
print(
    f"The original data has {enriched_fact.shape[1]} columns. The number and string data "
    f"have total of {df_pd_enriched_num.shape[1] + df_pd_enriched_str.shape[1]} columns."
)
# Out:
# The original data has 16 columns. The number and string data have total of 16 columns.

# %% [markdown]
# We observe 5772 observations (rows) in the data frame.

# %%
print(f"Number of observations: {enriched_fact.shape[0]}")
# Out:
# Number of observations: 5772

# %%
# We use the number of observations more often, so we define a variable.
n_enriched_obs = enriched_fact.shape[0]

# %% [markdown]
# ### How many missing values do each of the variables have (variable completeness) and what are the variable types? Is `Ziekteverzuimpercentage_1` complete? And what other, missing-like values do you observe in the string data? Create a frequency table of missing data per variable.

# %% [markdown]
# **numerical data**:
#
# Pandas' `describe()` function outputs some descriptive statistics. For numerical data these stats include: count of non-null values, mean, standard deviation, range (i.e., min and max), the lower quartile, the median, and the upper quartile. What can we conclude for the 'SalePrice' variable (min, max, median vs average)?

# %% [markdown]
# **numerical data:**
#
# Not all numerical variables are complete. For example, `LotFrontage` has 490 missing values. All numerical variables are of type "int64".

# %%
# Pandas.
df_pd_missing_data_num = (
    
    pd.DataFrame({

        'data_type':    df_pd_enriched_num.dtypes,
        'missing':      df_pd_enriched_num.isnull().sum()   
    })

    # Add complete%
    .assign(
        complete_pct = lambda x: round(100 * (n_enriched_obs - x['missing']) / n_enriched_obs, 2)
    )

    # Remove variables that are complete.
    .query("complete_pct < 100")

    # Sort table by data completeness in descending order.
    .sort_values(by = 'complete_pct')
)

print(df_pd_missing_data_num)
print("")
# Out:
#                           data_type  missing  complete_pct
# Ziekteverzuimpercentage_1   float64      310         94.63

# %% [markdown]
# **String data:**
#
# Are all string variables are complete? Let's investigate the unique values. In case of Pandas we observe `nan` in addition to non-null data.

# %%
# Pandas
print("Pandas:")

for name in l_df_str_names:
    print(f"{name}: {df_pd_enriched_str[name].unique()}")
# Out:
# Pandas:
# BedrijfskenmerkenSBI2008: ['T001081' '301000' '305700' '300003' '307500' '307610' '317105' '320005'
#  '328110' '346600' '348000' '350000' '300007' '354200' '354300' '356900'
#  '371600' '383100' '383200' '389100' '391600' '396300' '402000' '403300'
#  '410200' '415300' '300013' '417400' '419000' '422400' '422500' '422600'
#  '425300' '426600' '428100' '435500' 'WP19078' 'WP19091' 'WP19098']
# Perioden: ['1996KW01' '1996KW02' '1996KW03' '1996KW04' '1996JJ00' '1997KW01'
#  '1997KW02' '1997KW03' '1997KW04' '1997JJ00' '1998KW01' '1998KW02'
#  '1998KW03' '1998KW04' '1998JJ00' '1999KW01' '1999KW02' '1999KW03'
#  '1999KW04' '1999JJ00' '2000KW01' '2000KW02' '2000KW03' '2000KW04'
#  '2000JJ00' '2001KW01' '2001KW02' '2001KW03' '2001KW04' '2001JJ00'
#  '2002KW01' '2002KW02' '2002KW03' '2002KW04' '2002JJ00' '2003KW01'
#  '2003KW02' '2003KW03' '2003KW04' '2003JJ00' '2004KW01' '2004KW02'
#  '2004KW03' '2004KW04' '2004JJ00' '2005KW01' '2005KW02' '2005KW03'
#  '2005KW04' '2005JJ00' '2006KW01' '2006KW02' '2006KW03' '2006KW04'
#  '2006JJ00' '2007KW01' '2007KW02' '2007KW03' '2007KW04' '2007JJ00'
#  '2008KW01' '2008KW02' '2008KW03' '2008KW04' '2008JJ00' '2009KW01'
#  '2009KW02' '2009KW03' '2009KW04' '2009JJ00' '2010KW01' '2010KW02'
#  '2010KW03' '2010KW04' '2010JJ00' '2011KW01' '2011KW02' '2011KW03'
#  '2011KW04' '2011JJ00' '2012KW01' '2012KW02' '2012KW03' '2012KW04'
#  '2012JJ00' '2013KW01' '2013KW02' '2013KW03' '2013KW04' '2013JJ00'
#  '2014KW01' '2014KW02' '2014KW03' '2014KW04' '2014JJ00' '2015KW01'
#  '2015KW02' '2015KW03' '2015KW04' '2015JJ00' '2016KW01' '2016KW02'
#  '2016KW03' '2016KW04' '2016JJ00' '2017KW01' '2017KW02' '2017KW03'
#  '2017KW04' '2017JJ00' '2018KW01' '2018KW02' '2018KW03' '2018KW04'
#  '2018JJ00' '2019KW01' '2019KW02' '2019KW03' '2019KW04' '2019JJ00'
#  '2020KW01' '2020KW02' '2020KW03' '2020KW04' '2020JJ00' '2021KW01'
#  '2021KW02' '2021KW03' '2021KW04' '2021JJ00' '2022KW01' '2022KW02'
#  '2022KW03' '2022KW04' '2022JJ00' '2023KW01' '2023KW02' '2023KW03'
#  '2023KW04' '2023JJ00' '2024KW01' '2024KW02' '2024KW03' '2024KW04'
#  '2024JJ00' '2025KW01' '2025KW02' '2025KW03']
# Title: ['1996 1e kwartaal' '1996 2e kwartaal' '1996 3e kwartaal'
#  '1996 4e kwartaal' '1996' '1997 1e kwartaal' '1997 2e kwartaal'
#  '1997 3e kwartaal' '1997 4e kwartaal' '1997' '1998 1e kwartaal'
#  '1998 2e kwartaal' '1998 3e kwartaal' '1998 4e kwartaal' '1998'
#  '1999 1e kwartaal' '1999 2e kwartaal' '1999 3e kwartaal'
#  '1999 4e kwartaal' '1999' '2000 1e kwartaal' '2000 2e kwartaal'
#  '2000 3e kwartaal' '2000 4e kwartaal' '2000' '2001 1e kwartaal'
#  '2001 2e kwartaal' '2001 3e kwartaal' '2001 4e kwartaal' '2001'
#  '2002 1e kwartaal' '2002 2e kwartaal' '2002 3e kwartaal'
#  '2002 4e kwartaal' '2002' '2003 1e kwartaal' '2003 2e kwartaal'
#  '2003 3e kwartaal' '2003 4e kwartaal' '2003' '2004 1e kwartaal'
#  '2004 2e kwartaal' '2004 3e kwartaal' '2004 4e kwartaal' '2004'
#  '2005 1e kwartaal' '2005 2e kwartaal' '2005 3e kwartaal'
#  '2005 4e kwartaal' '2005' '2006 1e kwartaal' '2006 2e kwartaal'
#  '2006 3e kwartaal' '2006 4e kwartaal' '2006' '2007 1e kwartaal'
#  '2007 2e kwartaal' '2007 3e kwartaal' '2007 4e kwartaal' '2007'
#  '2008 1e kwartaal' '2008 2e kwartaal' '2008 3e kwartaal'
#  '2008 4e kwartaal' '2008' '2009 1e kwartaal' '2009 2e kwartaal'
#  '2009 3e kwartaal' '2009 4e kwartaal' '2009' '2010 1e kwartaal'
#  '2010 2e kwartaal' '2010 3e kwartaal' '2010 4e kwartaal' '2010'
#  '2011 1e kwartaal' '2011 2e kwartaal' '2011 3e kwartaal'
#  '2011 4e kwartaal' '2011' '2012 1e kwartaal' '2012 2e kwartaal'
#  '2012 3e kwartaal' '2012 4e kwartaal' '2012' '2013 1e kwartaal'
#  '2013 2e kwartaal' '2013 3e kwartaal' '2013 4e kwartaal' '2013'
#  '2014 1e kwartaal' '2014 2e kwartaal' '2014 3e kwartaal'
#  '2014 4e kwartaal' '2014' '2015 1e kwartaal' '2015 2e kwartaal'
#  '2015 3e kwartaal' '2015 4e kwartaal' '2015' '2016 1e kwartaal'
#  '2016 2e kwartaal' '2016 3e kwartaal' '2016 4e kwartaal' '2016'
#  '2017 1e kwartaal' '2017 2e kwartaal' '2017 3e kwartaal'
#  '2017 4e kwartaal' '2017' '2018 1e kwartaal' '2018 2e kwartaal'
#  '2018 3e kwartaal' '2018 4e kwartaal' '2018' '2019 1e kwartaal'
#  '2019 2e kwartaal' '2019 3e kwartaal' '2019 4e kwartaal' '2019'
#  '2020 1e kwartaal' '2020 2e kwartaal' '2020 3e kwartaal'
#  '2020 4e kwartaal' '2020' '2021 1e kwartaal' '2021 2e kwartaal'
#  '2021 3e kwartaal' '2021 4e kwartaal' '2021' '2022 1e kwartaal'
#  '2022 2e kwartaal' '2022 3e kwartaal' '2022 4e kwartaal' '2022'
#  '2023 1e kwartaal' '2023 2e kwartaal' '2023 3e kwartaal'
#  '2023 4e kwartaal' '2023' '2024 1e kwartaal' '2024 2e kwartaal'
#  '2024 3e kwartaal' '2024 4e kwartaal' '2024' '2025 1e kwartaal'
#  '2025 2e kwartaal' '2025 3e kwartaal']
# Description: ['' None 'Voorlopige cijfers']
# Status: ['Definitief' 'Voorlopig']
# Key_bedrijfs: ['T001081' '301000' '305700' '300003' '307500' '307610' '317105' '320005'
#  '328110' '346600' '348000' '350000' '300007' '354200' '354300' '356900'
#  '371600' '383100' '383200' '389100' '391600' '396300' '402000' '403300'
#  '410200' '415300' '300013' '417400' '419000' '422400' '422500' '422600'
#  '425300' '426600' '428100' '435500' 'WP19078' 'WP19091' 'WP19098']
# Title_bedrijfs: ['A-U Alle economische activiteiten' 'A Landbouw, bosbouw en visserij'
#  'B Delfstoffenwinning' 'B-F Nijverheid en energie' 'C Industrie'
#  '10-12 Voedings-, genotmiddelenindustrie'
#  '17-18 Papier- en grafische industrie' '19-22 Raffinaderijen en chemie'
#  '24-30, 33 Metaal-elektro industrie' 'D Energievoorziening'
#  'E Waterbedrijven en afvalbeheer' 'F Bouwnijverheid'
#  'G-N Commerciële dienstverlening' 'G Handel'
#  '45 Autohandel en -reparatie' '46 Groothandel en handelsbemiddeling'
#  "47 Detailhandel (niet in auto's)" 'H Vervoer en opslag'
#  '49 Vervoer over land' 'I Horeca' 'J Informatie en communicatie'
#  'K Financiële dienstverlening' 'L Verhuur en handel van onroerend goed'
#  'M Specialistische zakelijke diensten'
#  'N Verhuur en overige zakelijke diensten' '812 Schoonmaakbedrijven'
#  'O-U Niet-commerciële dienstverlening'
#  'O Openbaar bestuur en overheidsdiensten' 'P Onderwijs'
#  'Q Gezondheids- en welzijnszorg' '86 Gezondheidszorg' '861 Ziekenhuizen'
#  '87 Verpleging en zorg met overnachting'
#  '88 Welzijnszorg zonder overnachting' 'R Cultuur, sport en recreatie'
#  'S Overige dienstverlening' '1 tot 10 werkzame personen'
#  '10 tot 100 werkzame personen' '100 of meer werkzame personen']
# Description_bedrijfs: ["Alle economische activiteiten \r\nDeze categorie is een samentelling van categorieën: \r\nA Landbouw, bosbouw en visserij \r\nB Winning van delfstoffen \r\nC Industrie \r\nD Productie en distributie van en handel in elektriciteit, aardgas, stoom en gekoelde lucht \r\nE Winning en distributie van water; afval- en afvalwaterbeheer en sanering \r\nF Bouwnijverheid \r\nG Groot- en detailhandel; reparatie van auto's \r\nH Vervoer en opslag \r\nI Logies-, maaltijd- en drankverstrekking \r\nJ Informatie en communicatie \r\nK Financiële instellingen \r\nL Verhuur van en handel in onroerend goed \r\nM Advisering, onderzoek en overige specialistische zakelijke dienstverlening \r\nN Verhuur van roerende goederen en overige zakelijke dienstverlening \r\nO Openbaar bestuur, overheidsdiensten en verplichte sociale verzekeringen \r\nP Onderwijs \r\nQ Gezondheids- en welzijnszorg \r\nR Cultuur, sport en recreatie \r\nS Overige dienstverlening \r\nT Huishoudens als werkgever; niet-gedifferentieerde productie van goederen en diensten door huishoudens voor eigen gebruik \r\nU Extraterritoriale organisaties en lichamen"
#  'Landbouw, bosbouw en visserij \r\nDeze sectie omvat: \r\n- de exploitatie van natuurlijke plantaardige en dierlijke hulpbronnen: \r\n w.o. de akkerbouw, veeteelt en de productie van overige planten en dieren op een agrarisch bedrijf of in het natuurlijke leefgebied; \r\n w.o. bosbouw, houtteelt en jacht; \r\n w.o. specifieke loondiensten met betrekking tot het productieproces landbouw, jacht en bosbouw worden eveneens in deze sectie ingedeeld; \r\n w.o. visserij: de vangst of het kweken van vis, schaaldieren en weekdieren.'
#  'Winning van delfstoffen \r\nDeze sectie omvat: \r\n- de winning van in de natuur voorkomende mineralen in vaste vorm (steenkool, turf en erts), in vloeibare vorm (aardolie) of in de vorm van een gas (aardgas). Winning vindt plaats door middel van ondergrondse mijnbouw, dagbouw of boringen. \r\nDeze sectie omvat voorts bijkomende bewerkingen die voor het vervoer en de afzet van de minerale producten noodzakelijk zijn, bijvoorbeeld het vergruizen, malen, wassen, drogen, sorteren of concentreren van ertsen, het vloeibaar maken van aardgas en het briketteren van vaste brandstoffen. \r\nDeze werkzaamheden worden vaak door de eenheden die de delfstoffen winnen zelf uitgeoefend en/of door andere eenheden in de buurt van de winplaats. \r\nDeze sectie omvat ook: \r\n- de vervaardiging van steenkool- en bruinkoolbriketten, het sinteren van ertsen; \r\n- het vergruizen, malen of op andere wijze behandelen van bepaalde soorten aarde, steen en mineralen. \r\nDeze sectie omvat niet: \r\n- de verwerking van delfstoffen (sectie C); \r\n- de productie aan de bron van natuurlijk bron- of mineraalwater (1107); \r\n- de winning, zuivering en distributie van water (3600).'
#  'Nijverheid en energie \r\nDeze categorie is een samentelling van categorieën: \r\nB Winning van delfstoffen \r\nC Industrie \r\nD Productie en distributie van en handel in elektriciteit, aardgas, stoom en gekoelde lucht \r\nE Winning en distributie van water; afval- en afvalwaterbeheer en sanering \r\nF Bouwnijverheid'
#  "Industrie \r\nDeze sectie omvat: \r\n- de mechanische, fysische of chemische verwerking van materialen, stoffen of onderdelen tot nieuwe producten. De verwerkte materialen, stoffen of onderdelen zijn grondstoffen uit de landbouw, bosbouw, visserij en mijnbouw, alsmede (half)fabricaten uit de industrie. \r\n- reparatie en installatie van machines, apparatuur en andere benodigdheden voor bedrijven (geen consumentengoederen). \r\nBij de eenheden in deze sectie gaat het vaak om fabrieken waar gewoonlijk machines en apparaten worden gebruikt. Eenheden waar materialen of stoffen met de hand of in de eigen woning tot nieuwe producten worden verwerkt en die producten op de plaats waar deze zijn gemaakt, zelf verkopen, zoals bakkerijen en kleermakerijen, vallen echter ook onder deze sectie. \r\nIndustriële eenheden kunnen materialen zelf verwerken of dit aan andere eenheden uitbesteden. In beide gevallen valt dit onder de sectie Industrie. \r\nReparatie van huishoudelijke apparaten en consumptiegoederen wordt ingedeeld in afdeling 95; \r\nde reparatie van (bedrijfs-)auto's en motoren in afdeling 45: de autobranche. \r\nDe vervaardiging van specifieke componenten en onderdelen, toebehoren en hulpstukken voor machines en apparaten wordt gewoonlijk ingedeeld in dezelfde klasse als de vervaardiging van de desbetreffende machines en apparaten. \r\nDe vervaardiging van niet-specifieke componenten en onderdelen voor machines en apparatuur, zoals motoren, zuigers, elektromotoren, \r\nelektra-installatiemateriaal, kleppen, kogellagers, rollagers, worden in de passende klasse van de sectie industrie ingedeeld. \r\nDe sectie omvat niet: \r\n- activiteiten die niet leiden tot een nieuw product, maar tot een gewijzigde versie van hetzelfde product: \r\n* het opsplitsen van partijen stukgoederen in kleinere partijen, inclusief het verpakken, herverpakken; \r\n* het bottelen van producten als alcoholhoudende dranken of chemicaliën; \r\n* de montage van computers volgens de specifieke wensen van een klant; \r\n* het mengen van verf; \r\nDeze activiteiten worden ingedeeld in sectie G (groothandel en detailhandel)."
#  'Vervaardiging van voedingsmiddelen, dranken en tabaksproducten \r\nDeze categorie is een samentelling van categorieën: \r\n10 Vervaardiging van voedingsmiddelen \r\n11 Vervaardiging van dranken \r\n12 Vervaardiging van tabaksproducten'
#  'Vervaardiging van papier, karton en papier- en kartonwaren; drukkerijen en reproductie van opgenomen media \r\nDeze categorie is een samentelling van categorieën: \r\n17 Vervaardiging van papier, karton en papier- en kartonwaren \r\n18 Drukkerijen, reproductie van opgenomen media'
#  'Raffinaderijen, chemie, vervaardiging van farmaceutische producten en rubber- en kunststofproducten \r\nDeze categorie is een samentelling van categorieën: \r\n19 Vervaardiging van cokesovenproducten en aardolieverwerking \r\n20 Vervaardiging van chemische producten \r\n21 Vervaardiging van farmaceutische grondstoffen en producten \r\n22 Rubber- en kunststofproductindustrie'
#  "Metaal-elektro industrie\r\nDeze categorie is een samentelling van categorieën:\r\n24 Vervaardiging van metalen in primaire vorm\r\n25 Vervaardiging van producten van metaal (geen machines en apparaten)\r\n26 Vervaardiging van computers en van elektronische en optische apparatuur\r\n27 Vervaardiging van elektrische apparatuur\r\n28 Vervaardiging van overige machines en apparaten\r\n29 Vervaardiging van auto's, aanhangwagens en opleggers\r\n30 Vervaardiging van overige transportmiddelen\r\n33 Reparatie en installatie van machines en apparaten"
#  'Productie en distributie van en handel in elektriciteit, aardgas, stoom en gekoelde lucht \r\nDeze sectie omvat: \r\n- productie en distributie van en handel in elektriciteit, aardgas en warm water.'
#  'Winning en distributie van water; afval- en afvalwaterbeheer en sanering \r\nDeze sectie omvat: \r\n- winning en distributie van water; \r\n- afvalbehandeling en recycling.'
#  'Bouwnijverheid \r\nDeze sectie omvat: \r\n- algemene en gespecialiseerde bouwkundige en civieltechnische werken, de bouwinstallatie en de afwerking van gebouwen. \r\nZij omvat ook nieuwbouw, reparatie, aan- en verbouwwerkzaamheden, het optrekken van geprefabriceerde gebouwen of constructies ter plaatse en van tijdelijke bouwwerken. \r\nOnder algemene bouw valt de bouw van woningen, kantoren, winkels en andere vormen van burgerlijke- en utiliteitsbouw enzovoort of de bouw of aanleg van zware constructies als autowegen, straten, bruggen, tunnels, spoorwegen, vliegvelden, havens en andere waterbouwkundige projecten, irrigatiesystemen, rioleringen, industriële installaties, pijpleidingen en elektriciteitsleidingen, sportvoorzieningen enzovoort. Deze werkzaamheden kunnen voor eigen rekening of voor een vast bedrag of op contractbasis worden uitgevoerd. Een deel van de werkzaamheden of soms zelfs alle uitvoerende werkzaamheden kunnen worden uitbesteed aan onderaannemers. \r\nGespecialiseerde bouw omvat de bouw of aanleg van een gedeelte van bouwwerken en van civieltechnische werken of de hiervoor vereiste voorbereidende werkzaamheden. Er is gewoonlijk sprake van gespecialiseerde werkzaamheden ten behoeve van diverse bouwwerken, waarvoor specifieke ervaring of een speciale uitrusting nodig is. Het heien, leggen van funderingen, boren van waterputten, de cascobouw, het storten van beton, metselen, zetten van natuursteen, de bouw van steigers, dakbedekking enzovoort worden hiertoe gerekend. Gespecialiseerde bouwkundige werkzaamheden worden meestal aan onderaannemers uitbesteed, maar vooral reparaties worden in de bouw rechtstreeks voor de eigenaar van het onroerend goed uitgevoerd. \r\nDe bouwinstallatie omvat de installatie van alle voorzieningen waardoor een bouwwerk als zodanig zijn functie kan vervullen. Deze werkzaamheden worden meestal op de bouwplaats zelf verricht, hoewel bepaalde gedeelten ervan in een werkplaats kunnen worden uitgevoerd. Inbegrepen zijn loodgieterswerk, de installatie van verwarmings- en klimaatregelingssystemen, alarmsystemen en andere elektrische apparatuur, sprinklerinstallaties, liften en roltrappen enzovoort. Ook vallen hieronder isolatiewerkzaamheden (vochtwering, warmte- en geluidsisolatie), het aanbrengen van metalen beplating, de installatie van commerciële koelapparatuur, verlichtings- en signaleringssystemen voor wegen, spoorwegen, luchthavens, havens enzovoort. Het uitvoeren van reparaties in verband met deze activiteiten is ook inbegrepen. \r\nDe afwerking van gebouwen omvat werkzaamheden die zijn gericht op de afwerking of voltooiing van een bouwwerk, zoals glaszetten, stukadoorswerk, schilderen, sauzen, het aanbrengen van vloer- of wandtegels of van andere bekleding of bedekking zoals parket, tapijt, behang enzovoort, schuren van vloeren, aftimmeren, geluidstechnische werkzaamheden enzovoort. Het uitvoeren van reparaties in verband met deze activiteiten is ook inbegrepen. \r\nDeze sectie omvat niet: \r\n- de bouw of installatie van industriële apparatuur en machines (bijvoorbeeld de installatie van industriële ovens, turbines enzovoort) \r\n(sectie C); \r\n- het optrekken van volledige geprefabriceerde gebouwen of bouwwerken van zelf vervaardigde onderdelen wordt ingedeeld bij de toepasselijke rubriek van de sectie Industrie, afhankelijk van het materiaal waaruit deze voornamelijk bestaan. Indien dit echter beton is, wordt deze activiteit in deze afdeling ingedeeld.'
#  "Commerciële dienstverlening \r\nDeze categorie is een samentelling van categorieën: \r\nG Groot- en detailhandel; reparatie van auto's \r\nH Vervoer en opslag \r\nI Logies-, maaltijd- en drankverstrekking \r\nJ Informatie en communicatie \r\nK Financiële instellingen \r\nL Verhuur van en handel in onroerend goed \r\nM Advisering, onderzoek en overige specialistische zakelijke dienstverlening \r\nN Verhuur van roerende goederen en overige zakelijke dienstverlening"
#  "Groot- en detailhandel; reparatie van auto's \r\nDeze sectie omvat: \r\n- de groot- en detailhandel (verkoop zonder aanbrengen van veranderingen) in alle soorten goederen en de diensten die bij de verkoop van goederen worden verleend; \r\n- tussenhandel/handelsbemiddeling; \r\n- reparatie van auto's en motoren. \r\nDe verkoop zonder bewerking omvat de in de handel gebruikelijke handelingen, bijvoorbeeld sorteren, samenvoegen en combineren van goederen, mengen (versnijden) van goederen (bijvoorbeeld wijn of zand), bottelen (met of zonder reiniging van de fles vooraf), verpakken, opsplitsen en anders verpakken van partijen stukgoederen voor distributie in kleinere hoeveelheden, opslag (al dan niet bevroren of gekoeld), schoonmaken en drogen van landbouwproducten, snijden van houtvezel- of metalen platen voor eigen rekening. \r\nGroothandel is de wederverkoop (verkoop zonder aanbrengen van veranderingen) van nieuwe en gebruikte goederen aan de detailhandel, aan industriële en andere bedrijfsmatige gebruikers, of aan andere groothandelaren, alsmede de handelsbemiddeling bij de aankoop van goederen voor of de verkoop van goederen aan dergelijke personen of bedrijven. De belangrijkste soort van groothandel is de groothandel in goederen, dat wil zeggen groothandelaren die goederen verkopen die zij in eigendom hebben zoals grossiers, dealers, exporteurs, importeurs en coöperatieve inkooporganisaties, verkooporganisaties en verkoopkantoren (detailhandelsbedrijven uitgezonderd) van industriële ondernemingen, die tot taak hebben de producten ervan op de markt te brengen. \r\nTussenhandel/handelsbemiddeling is het samenbrengen van koper en verkoper of het uitvoeren van transacties voor rekening van derden. Inbegrepen zijn makelaars op goederenbeurzen, commissionairs, en andere op commissiebasis werkzame tussenpersonen. \r\nDetailhandel is de wederverkoop (verkoop zonder aanbrengen van veranderingen) van nieuwe en gebruikte goederen hoofdzakelijk aan het publiek voor persoonlijk of huishoudelijk ge- of verbruik, op de markt of door winkels, warenhuizen, postorderbedrijven, straathandelaren, consumentencoöperaties, veilinghuizen enzovoort. De meeste detailhandelaren zijn eigenaar van de goederen die zij verkopen, maar sommigen werken als tussenpersoon voor een opdrachtgever en verkopen in consignatie dan wel op commissiebasis."
#  "Handel in en reparatie van auto's, motorfietsen en aanhangers"
#  "Groothandel en handelsbemiddeling (niet in auto's en motorfietsen) \r\nDeze afdeling omvat de groepen: \r\n461 Handelsbemiddeling \r\n462 Groothandel in landbouwproducten en levende dieren \r\n463 Groothandel in voedings- en genotmiddelen \r\n464 Groothandel in consumentenartikelen \r\n465 Groothandel in ICT-apparatuur \r\n466 Groothandel in machines en benodigdheden voor industrie en handel \r\n467 Overige gespecialiseerde groothandel \r\n469 Niet-gespecialiseerde groothandel"
#  'Detailhandel (niet in auto\'s) \r\nTot de detailhandel wordt gerekend: \r\nDe verkoop van niet zelfvervaardigde goederen, zowel nieuw als tweedehands, aan consumenten. \r\nDe volgende distributievormen worden onderscheiden: \r\n- winkelverkoop (471 - 477); \r\n- markthandel (478); \r\n- verkoop via internet, thuiswinkels, postorderverkoop, telefonische verkoop, verkoop via radio en televisie (479); \r\n- colportage, verkoop via huisparty\'s (4799.1); \r\n- straathandel (4799.2); \r\n- automatenverkoop, verkoop vanuit woonhuis, magazijn, werkplaats (4799.9). \r\nTot de detailhandel wordt ook gerekend de tussenpersonen/bemiddeling in de detailhandel (4799.9, internetveilingen: 4791). \r\nTot de detailhandel in winkel wordt gerekend: \r\nVerkoop van voor aflevering gereed zijnde goederen (die naar aard en vorm niet bedoeld zijn om ter plaatse te worden geconsumeerd) aan elke zich aandienende finale consument, gekoppeld aan de expositie van een assortiment, in of vanuit een ommuurde en overspannen ruimte en waarbij deze ruimte zelf of het complex waarin deze ruimte is opgenomen voor het publiek toegankelijk moet zijn. \r\nTot de detailhandel in winkel wordt ook gerekend: \r\n- een boekenkiosk binnen de stationshal; \r\n- een fruitkraam in de hal van een ziekenhuis; \r\n- een noodwinkel; \r\n- een "shop in de shop". \r\nTot de detailhandel in winkel wordt niet gerekend: \r\n- de verkoop vanuit markthallen via al dan niet verplaatsbare kramen; wordt tot de markthandel gerekend; \r\n- de verkoop op beurzen en tentoonstellingen; wordt tot de overige vormen van detailhandel gerekend; \r\n- de verkoop van auto\'s, motoren en motorbrandstoffen; wordt tot afdeling 50 gerekend; \r\n- de verkoop vanuit woonhuis (met geen voor het publiek toegankelijke ruimte), vanuit magazijn of werkplaats; deze verkoop aan particulieren wordt tot de overige vormen van detailhandel gerekend.'
#  "Vervoer en opslag \r\nDeze sectie omvat: \r\n- het vervoer van personen of goederen, al dan niet volgens een dienstregeling, per spoor, via een pijpleiding, over de weg, over water of door de lucht; \r\n- de ondersteunende activiteiten als terminal- en parkeerfaciliteiten, vrachtbehandeling, opslag enz.; \r\n- de posterijen; \r\n- de verhuur van transportmiddelen met bestuurder of bedienend personeel. \r\nDeze sectie omvat niet: \r\n- het onderhoud en de reparatie van auto's (45)."
#  'Vervoer over land \r\nDeze afdeling omvat: \r\n- personen- en goederenvervoer over de weg en per spoor. \r\nDeze klasse omvat niet: \r\n- exploitatie van toeristische spoorlijnen (93.21.1).'
#  'Logies-, maaltijd- en drankverstrekking \r\nDeze sectie omvat: \r\n- het aan gasten verschaffen van logies en/of bereide maaltijden, snacks en dranken voor onmiddellijke consumptie. \r\nDe verschillende activiteiten in sectie I overlappen elkaar in zekere mate, omdat bijvoorbeeld de verkoop van dranken een activiteit op zich is, maar ook deel uitmaakt van de activiteiten van een restaurant (waar bij de \r\nmaaltijden dranken worden verstrekt) en dan met de verkoop van maaltijden bij 56.1 (Restaurants) wordt ingedeeld. Evenzo vormt de exploitatie van een restaurant een aparte activiteit, maar kan zij ook deel uitmaken van een bedrijf dat logies verschaft. \r\nLogiesverschaffende eenheden bieden reizigers, vakantiegangers en anderen accommodatie voor kortstondig verblijf (korter dan 3 maanden) aan. Er zijn vele verschillende eenheden. Sommige verschaffen alleen logies, terwijl andere naast logies ook maaltijden en recreatieve faciliteiten aanbieden. Het soort aanvullende dienstverlening kan van eenheid tot eenheid verschillen. \r\nRestaurants verstrekken volledige, voor onmiddellijke consumptie geschikte maaltijden, ongeacht of het traditionele restaurants, zelfbedienings- of afhaalrestaurants, dan wel permanente of tijdelijke viskramen en \r\ndergelijke met of zonder zitplaatsen zijn. Bepalend is het feit dat er voor onmiddellijke consumptie geschikte maaltijden worden aangeboden, niet het soort gelegenheid dat deze maaltijden verstrekt. \r\nDeze sectie omvat niet: \r\n- de productie van maaltijden niet voor onmiddellijke consumptie geschikt of maaltijden of bereid voedsel dat niet als maaltijd wordt beschouwd (SBI 10: voedingsmiddelenindustrie); \r\n- de verkoop van niet zelf vervaardigd voedsel dat niet als maaltijd wordt beschouwd of van niet voor onmiddellijke consumptie geschikte maaltijden (SBI 46 groothandel of SBI 47 detailhandel afhankelijk van de afnemerscategorie).'
#  'Informatie en communicatie \r\nDeze sectie omvat: \r\n- de productie en distributie van informatie, de voorziening van de infrastructuur om die informatie door te geven, alsmede activiteiten op het gebied van data- en communicatie-informatietechnologie en het bewerken van data en andere informatie. \r\nDe belangrijkste activiteiten die hier ingedeeld worden zijn het uitgeven (afdeling 58, incl. het uitgeven van software), productie van films en geluidsopnamen (afdeling 59) radio en TV (afdeling 60), telecommunicatie (afdeling 61), informatietechnologie (afdeling 62) en andere dienstverlening op het gebied van informatie (afdeling 63). Uitgeven omvat ook het verkrijgen van de copyrights voor de content (informatieproducten) en het toegankelijk maken hiervan voor een breed publiek. Alle mogelijke vormen van uitgeven vallen onder deze sectie (in drukvorm, elektronisch of audio, op het internet, als multimediaproduct enzovoorts).'
#  'Financiële instellingen \r\nDeze sectie omvat: \r\n- financiële instellingen; \r\n- verzekeringswezen en pensioenfondsen (geen verplichte sociale verzekeringen); \r\n- financiële beurzen, effectenmakelaars, assurantietussenpersonen, administratiekantoren voor aandelen, waarborgfondsen en dergelijke.'
#  'Verhuur van en handel in onroerend goed \r\nDeze sectie omvat: \r\n- verhuur van onroerend goed; \r\n- bemiddeling in en beheer van onroerend goed.'
#  'Advisering, onderzoek en overige specialistische zakelijke dienstverlening \r\nDeze sectie omvat: \r\n- gespecialiseerde professionele wetenschappelijke en technische activiteiten. Deze activiteiten vereisen een hoge opleiding en stellen specifieke kennis ter beschikking.'
#  'Verhuur van roerende goederen en overige zakelijke dienstverlening \r\nDeze sectie omvat: \r\n- activiteiten die zakelijke gebruikers ondersteunen bij de bedrijfsvoering. Het verschil van deze activiteiten met die uit sectie M is dat de activiteiten uit deze sectie niet primair gericht zijn op het overbrengen van expertise en kennis.'
#  "Reiniging \r\nDeze klasse omvat: \r\n- glazenwassen; \r\n- schoorsteenvegen en schoonmaken van rookkanalen; \r\n- brand- en roetreiniging (niet met behulp van zandstralen of stoom); \r\n- gevelreiniging met behulp van het onder hoge druk spuiten van water; \r\n- verwijdering van graffiti; \r\n- reinigen van industriële installaties en van tanks en silo's; \r\n- de gaswacht (schoonmaken en controle van gastoestellen); \r\n- schoonmaken van kachels, ovens, boilers, e.d.; \r\n- reinigen van interieurs van woningen, kantoren en andere gebouwen of gedeelten daarvan; \r\n- schoonmaken van toiletten inclusief verversen handdoeken, toiletpapier, zeepautomaat e.d. \r\n- schoonmaken van tanks van schepen en vrachtwagens; \r\n- classificeren van schepen; \r\n- reinigen van treinen, bussen, vliegtuigen, e.d.; \r\n- schoonmaken van vuilcontainers; \r\n- schoonmaken van verpakkingsmiddelen flessen, kratten, pallets e.d.; \r\n- bestrijden van vogeloverlast bij vliegvelden, gebouwen e.d.; \r\n- desinfecteren en bestrijden van ongedierte (niet ten behoeve van de landbouw); \r\n- steriliseren van medische instrumenten en hulpmiddelen; \r\n- schoonmaken van graven en grafmonumenten; \r\n- de bierwacht (schoonmaken en controle van bierleidingen). \r\nDeze klasse omvat niet: \r\n- verwijderen van asbest (39.00); \r\n- reinigen van gevels met stoom, door zandstralen e.d. (43.39); \r\n- reinigen van gebouwen en opruimen van bouwplaatsen na de bouw (43.39); \r\n- particuliere huishoudens met schoonmaakpersoneel in dienst (97.00)."
#  'Niet-commerciële dienstverlening \r\nDeze categorie is een samentelling van categorieën: \r\nO Openbaar bestuur, overheidsdiensten en verplichte sociale verzekeringen \r\nP Onderwijs \r\nQ Gezondheids- en welzijnszorg \r\nR Cultuur, sport en recreatie \r\nS Overige dienstverlening \r\nT Huishoudens als werkgever; niet-gedifferentieerde productie van goederen en diensten door huishoudens voor eigen gebruik \r\nU Extraterritoriale organisaties en lichamen'
#  'Openbaar bestuur, overheidsdiensten en verplichte sociale verzekeringen \r\nDeze sectie omvat: \r\n- eenheden die deel uitmaken van de lagere of centrale overheid en die tot een goede werking van het bestuur van de samenleving bijdragen en ook het beheer van de verplichte sociale verzekeringsregelingen; \r\n- defensie, justitie, politie, buitenlandse zaken enzovoort; \r\n- het algemeen openbaar bestuur (bijvoorbeeld uitvoerende, wetgevende, financiële taken enzovoort op alle bestuursniveaus) en het toezicht op het economische en sociale leven; \r\n- provincies en gemeentes; \r\n- het beheer van de verplichte socialeverzekeringsregelingen. \r\nActiviteiten die elders in de SBI zijn geclassificeerd vallen niet onder afdeling 75, ook al worden zij door overheidinstanties uitgevoerd. Enkele voorbeelden: \r\n- het beheer van het onderwijsstelsel (d.w.z. regelgeving, inspecties, onderwijsprogramma\'s) valt onder deze sectie O, maar het onderwijs zelf valt onder afdeling 85 "Onderwijs"; \r\n- militaire en penitentiaire ziekenhuizen worden ingedeeld bij afdeling 86 "Gezondheidszorg"; \r\n- inzameling en verwerking van afvalwater en afval valt onder afdeling 38 "Milieudienstverlening".'
#  "Onderwijs \r\nDeze sectie omvat: \r\n- alle vormen van openbaar en particulier onderwijs, op elk niveau en voor elk beroep, zowel mondeling en schriftelijk als via radio en televisie; zowel het onderwijs door de instellingen op de verschillende niveaus van het normale schoolstelsel als volwasseneneducatie, alfabetiseringsprogramma's e.d. \r\nVolwasseneneducatie waarvan de inhoud vergelijkbaar is met die van het onderwijs op een specifiek niveau wordt bij dat niveau ingedeeld. Op ieder niveau van het initiële onderwijs omvatten de klassen het speciale onderwijs aan lichamelijk of geestelijk gehandicapte leerlingen. \r\nDeze sectie omvat ook: \r\n- het overige onderwijs, zoals autorijscholen. \r\nDeze sectie omvat niet: \r\n- hoofdzakelijk op ontspanning gericht onderwijs, zoals bridge- en golflessen, dansonderwijs (93 of 94)."
#  'Gezondheids- en welzijnszorg \r\nDeze sectie omvat: \r\n- behandeling in algemene en gespecialiseerde ziekenhuizen; \r\n- geestelijke gezondheidszorg en verslavingszorg, eventueel in combinatie met overnachting; \r\n- behandeling door medische en paramedische praktijken; \r\n- ondersteunende activiteiten voor de gezondheidszorg, door bijvoorbeeld laboratoria en ambulancediensten; \r\n- verpleging, verzorging of begeleiding met huisvesting door bijvoorbeeld verpleeg- en verzorgingshuizen of via begeleid wonen; \r\n- welzijnszorg, zoals thuiszorg, lokaal welzijnswerk en hulp aan gehandicapten en ouderen; \r\n- kinderopvang.'
#  'Gezondheidszorg \r\nDeze afdeling omvat de groepen: \r\n861 Ziekenhuizen \r\n862 Medische en tandheelkundige praktijken \r\n869 Paramedische praktijken en overige ambulante gezondheidszorg'
#  'Ziekenhuizen en geestelijke gezondheids- en verslavingszorg met overnachting \r\nDeze groep omvat: \r\n86.10.1 Universitair medische centra \r\n86.10.2 Algemene ziekenhuizen \r\n86.10.3 Categorale ziekenhuizen \r\n86.10.4 Geestelijke gezondheids- en verslavingszorg met overnachting'
#  'Verpleging, verzorging en begeleiding met overnachting \r\nDeze afdeling omvat de groepen: \r\n871 Verpleeghuizen \r\n872 Huizen en dagverblijven voor verstandelijk gehandicapten en psychiatrische cliënten \r\n873 Huizen en dagverblijven voor niet-verstandelijk gehandicapten en verzorgingshuizen \r\n879 Jeugdzorg en maatschappelijke opvang met overnachting'
#  'Maatschappelijke dienstverlening zonder overnachting'
#  'Cultuur, sport en recreatie \r\nDeze sectie omvat een wijde range aan activiteiten op het gebied van cultuur en recreatie, zoals culturele voorstellingen, musea, sport en recreatieve evenementen.'
#  'Overige dienstverlening \r\nDeze sectie omvat (als restcategorie) de activiteiten van belangenverenigingen, reparatie van computers en consumentenartikelen en veel andere activiteiten op het gebied van persoonlijke dienstverlening die niet elders zijn ingedeeld.'
#  'Het aantal "werkzame personen" bestaat uit: \r\n- werknemers en directeuren die op de loonlijst staan; \r\n- werknemers die op de loonlijst staan van een andere onderneming of instelling, maar bij de eigen onderneming werkzaam zijn en als zodanig in feite tot het personeel behoren (ingeleend personeel);\r\n - werkzame eigenaren, firmanten, leden van maatschappen, vennoten en medewerkende gezinsleden; \r\n- uitzendkrachten. \r\nUitgeleend personeel ( Werknemers die op de loonlijst staan, maar werken bij een andere onderneming of instelling.) is hierin niet opgenomen.']
# DimensionKey: ['BedrijfskenmerkenSBI2008']
# Title_category: ['Totaal' 'Bedrijfssector' 'Bedrijfstak' 'Bedrijfsklasse'
#  'Bedrijfsgrootte']
# Description_category: ['' None]
# ParentID: ['0']

# %% [markdown]
# ### Conduct descriptive/summary statistics for numerical variables (e.g., mean, median, std, and range) and for string variables (e.g., number of unique values, mode, and their frequency)

# %% [markdown]
# **numerical data**:
#
# Pandas' `describe()` function outputs some descriptive statistics. For numerical data these stats include: count of non-null values, mean, standard deviation, range (i.e., min and max), the lower quartile, the median, and the upper quartile. What can we conclude for the 'SalePrice' variable (min, max, median vs average)?

# %%
df_pd_enriched_num.describe()
# Out:
#                 ID  Ziekteverzuimpercentage_1  CategoryGroupID  ID_category
# count  5772.000000                5462.000000      5772.000000  5772.000000
# mean   2885.500000                   4.580264         3.333333     3.333333
# std    1666.377208                   1.299420         0.857421     0.857421
# min       0.000000                   1.400000         1.000000     1.000000
# 25%    1442.750000                   3.600000         3.000000     3.000000
# 50%    2885.500000                   4.500000         3.000000     3.000000
# 75%    4328.250000                   5.400000         4.000000     4.000000
# max    5771.000000                  10.100000         5.000000     5.000000

# %% [markdown]
# **String data:**
#
# For string data, Pandas' `describe()` function includes: count of non-null values and unique values, value at high frequency ('top'), and its concerned frequency.

# %%
df_pd_enriched_str.describe()
# Out:
#        BedrijfskenmerkenSBI2008  Perioden             Title Description  \
# count                      5772      5772              5772        5733
# unique                       39       148               148           2
# top                     T001081  1996KW01  1996 1e kwartaal
# freq                        148        39                39        5616
#
#             Status Key_bedrijfs                     Title_bedrijfs  \
# count         5772         5772                               5772
# unique           2           39                                 39
# top     Definitief      T001081  A-U Alle economische activiteiten
# freq          5655          148                                148
#
#                                      Description_bedrijfs  \
# count                                                5772
# unique                                                 37
# top     Het aantal "werkzame personen" bestaat uit: \r...
# freq                                                  444
#
#                     DimensionKey Title_category Description_category ParentID
# count                       5772           5772                  148     5772
# unique                         1              5                    1        1
# top     BedrijfskenmerkenSBI2008    Bedrijfstak                             0
# freq                        5772           2664                  148     5772

# %% [markdown]
# ### Save data to pickle file

# %% [markdown]
# We save objects - that we need in subsequent exercises - to a pickle file.

# %%
import os
import pickle

# Create dictionary 'dc_80072ned' with objects that will be used in the next exercises.
dc_uwv_80072ned = {
    'enriched_fact': enriched_fact,
    'l_df_num_names': l_df_num_names,
    'l_df_str_names': l_df_str_names,
}

# Ensure directory exists then save dc_uwv_80072ned as 'dc-uwv-80072ned.pkl'
out_dir = '../data/1_bronze'
os.makedirs(out_dir, exist_ok=True)
file_path = os.path.join(out_dir, 'dc-uwv-80072ned.pkl')

if os.path.exists(file_path):
    print(f"Overwriting existing file: {file_path}")
else:
    print(f"Saving to: {file_path}")

with open(file_path, 'wb') as pickle_file:
    pickle.dump(dc_uwv_80072ned, pickle_file, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# Saving to: ../data/1_bronze\dc-uwv-80072ned.pkl
